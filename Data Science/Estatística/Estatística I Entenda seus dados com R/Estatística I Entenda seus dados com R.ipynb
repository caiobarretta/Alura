# %%
numero <- (3*7)/4
numero
# Out:
# [1] 5.25

# %%
lista <- c(1,2,3,4,5,6)
lista
# Out:
# [1] 1 2 3 4 5 6

# %%
lista * 2
# Out:
# [1]  2  4  6  8 10 12

# %%
aulas <- c(2, 4, 4, 6,6,6,6, 8, 8, 10)
hist(aulas)
# Out:
# Plot with title “Histogram of aulas”

# %% [markdown]
# ####  Operações básicas

# %%
(1+2)*3/2
# Out:
# [1] 4.5

# %% [markdown]
# ### Melhor tendência #1

# %%
tendencia1 = c(1, 1, 50, 50, 50, 50, 50, 50, 50, 60, 60, 65, 70, 200, 250, 300, 700)
hist(tendencia1)
# Out:
# Plot with title “Histogram of tendencia1”

# %% [markdown]
# ### Melhor tendência #2

# %%
tendencia2 = c()
