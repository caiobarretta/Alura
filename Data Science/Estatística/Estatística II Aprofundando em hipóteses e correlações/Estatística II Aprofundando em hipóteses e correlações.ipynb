# %%
x1 <- runif(30, 37.9, 38.8)
x1
# Out:
#  [1] 38.28647 38.08571 38.20362 37.99966 38.50679 37.90811 38.68080 38.79518
#  [9] 38.77915 38.50929 38.04014 37.94019 38.63582 38.62454 38.78793 37.99383
# [17] 38.60832 38.42144 38.75304 38.12058 38.44783 38.51571 38.05208 38.01671
# [25] 38.53711 38.54066 38.05842 38.68727 38.55772 38.76792

# %%
x2 <- runif(30, 36, 38.2)
x2
# Out:
#  [1] 37.95318 37.48837 37.92957 38.02951 37.21509 37.21596 37.10338 37.01243
#  [9] 37.08305 37.48316 36.43398 36.88686 38.05546 36.55246 37.10624 37.58689
# [17] 37.15413 37.05562 38.01920 37.91737 36.64548 36.29955 37.92018 38.09942
# [25] 36.84085 36.55822 37.00670 36.00528 36.72277 36.66718

# %%
t.test(x1, x2)
# Out:
# 	Welch Two Sample t-test
#
# data:  x1 and x2
# t = 9.8344, df = 43.12, p-value = 1.387e-12
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  0.9490249 1.4386078
# sample estimates:
# mean of x mean of y
#  38.39540  37.20158

# %%
?t.test

# %%
wilcox.test(x1, x2)
# Out:
# 	Wilcoxon rank sum test
#
# data:  x1 and x2
# W = 869, p-value = 5.998e-13
# alternative hypothesis: true location shift is not equal to 0

# %%
?wilcox.test
